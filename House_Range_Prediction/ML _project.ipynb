# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn.preprocessing import StandardScaler

# %%
np.random.seed(123)
df = pd.read_csv('/content/drive/My Drive/python/Data set/Housing.csv')
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms guestroom basement  parking  \
# 0  13300000  7420         4          2        no       no        2
# 1  12250000  8960         4          4        no       no        3
# 2  12250000  9960         3          2        no      yes        2
# 3  12215000  7500         4          2        no      yes        3
# 4  11410000  7420         4          1       yes      yes        2
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
empty_count = df.isnull()
print(f"Total empty cells in the data set : {empty_count.sum().sum()}")
print(f"Total empty cells in indivitual comulmn : \n{empty_count.sum()}")
# Out:
# Total empty cells in the data set : 0
# Total empty cells in indivitual comulmn :
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# guestroom           0
# basement            0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
a = df['area']
plt.subplot(3,2,1)
plt.hist(a)
plt.xlabel('Area size')
plt.ylabel('Frequency')
plt.title('Area')

b = df['bedrooms']
plt.subplot(3,2,2)
plt.hist(b)
plt.xlabel('Bedrooms numbers')
plt.title('Bedrooms')

c = df['bathrooms']
plt.subplot(3,2,5)
plt.hist(c)
plt.xlabel('Bathrooms numbers')
plt.ylabel('Frequency')
plt.title('Bathrooms')

d = df['parking']
plt.subplot(3,2,6)
plt.hist(d)
plt.xlabel('Parking numbers')
plt.title('Parking')

plt.suptitle('Frequency distributions of the dataset’s features')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3323343025.py in <cell line: 0>()
# ----> 1 a = df['area']
#       2 plt.subplot(3,2,1)
#       3 plt.hist(a)
#       4 plt.xlabel('Area size')
#       5 plt.ylabel('Frequency')
#
# NameError: name 'df' is not defined

# %%
scale = StandardScaler()

df['guestroom'] = df['guestroom'].map({'yes': 1, 'no': 0})
df['basement'] = df['basement'].map({'yes': 1, 'no': 0})
df = pd.get_dummies(df, columns=['furnishingstatus'], drop_first=True)
print(df.head())

X = df[['area', 'bedrooms', 'bathrooms', 'guestroom', 'basement', 'parking', 'furnishingstatus']]
y = df['price']

df_scaledX = scale.fit_transform(X)
print(df_scaledX)

#regr = linear_model.LinearRegression()
#regr.fit(scaledX, y)

#scaled = scale.transform([[5300, 3]])

#predictedCO2 = regr.predict([scaled[0]])
#print(predictedCO2)
# Out:
#       price  area  bedrooms  bathrooms  guestroom  basement  parking  \
# 0  13300000  7420         4          2          0         0        2
# 1  12250000  8960         4          4          0         0        3
# 2  12250000  9960         3          2          0         1        2
# 3  12215000  7500         4          2          0         1        3
# 4  11410000  7420         4          1          1         1        2
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                            False                         False
# 1                            False                         False
# 2                             True                         False
# 3                            False                         False
# 4                            False                         False
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...
